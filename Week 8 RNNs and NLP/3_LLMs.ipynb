# %% [markdown]
# <h3>Large Language Models (LLMs)

# %% [markdown]
# LLMs with huggingface transformers:
# https://github.com/huggingface/transformers
# https://huggingface.co/docs/transformers/main/en/model_doc/llama3
